# %%
#Cashback offer — Hypotheses
#μ = average number of daily orders
#Null Hypothesis (H₀): μ ≤ μ₀ — The cashback offer has not increased the average daily orders.
#Alternative Hypothesis (H₁): μ > μ₀ — The cashback offer has increased the average daily orders.
# right tail

# %%
#2
#A Type I error occurs when we wrongly conclude that the new playlist algorithm increases listening time when in reality it does not.

# %%
#3
#At a 95% confidence level, the significance level is:
#α = 1 − 0.95 = 0.05

# %%
#4
#Significance level: α = 1 − 0.99 = 0.01
#If p-value < 0.01 → Reject H₀ → evidence supports the feature.
#If p-value ≥ 0.01 → Fail to reject H₀ → not enough evidence to support the feature.
