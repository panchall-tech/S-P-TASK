# %%
#[6500, 7200, 8000, 6000, 9000, 7500, 8200]
#Range = Maximum − Minimum
#9000-6000
steps = [6500, 7200, 8000, 6000, 9000, 7500, 8200]

range_steps = max(steps) - min(steps)

print("Range of steps:", range_steps)
# Out:
# Range of steps: 3000

# %%
import numpy as np

orders = [250, 400, 350, 300, 500]

variance = np.var(orders)
std_dev = np.std(orders)

print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 7400.0
# Standard Deviation: 86.02325267042627

# %%
import numpy as np

data_usage = [3.2, 2.8, 3.5, 3.0, 2.9, 3.1]

mean = np.mean(data_usage)
std_dev = np.std(data_usage)

cv = (std_dev / mean) * 100

print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Coefficient of Variation:", cv, "%")
# Out:
# Mean: 3.0833333333333335
# Standard Deviation: 0.22669117514559078
# Coefficient of Variation: 7.352146220938079 %

# %%
import numpy as np

likes = [120, 150, 130, 110, 170, 140, 135, 160, 125, 155]

mean = np.mean(likes)
std_dev = np.std(likes)

print("Mean likes:", mean)
print("Standard Deviation:", std_dev)
# Out:
# Mean likes: 139.5
# Standard Deviation: 18.090052515125542

# %%
import numpy as np

upi = [250, 1200, 450, 800, 300, 1500, 600, 900]

variance = np.var(upi)
std_dev = np.std(upi)

print("UPI Transaction Amounts:", upi)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# UPI Transaction Amounts: [250, 1200, 450, 800, 300, 1500, 600, 900]
# Variance: 169375.0
# Standard Deviation: 411.5519408288582
